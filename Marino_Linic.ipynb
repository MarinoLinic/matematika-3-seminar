# %%
from sympy import symbols, sqrt, asin, diff
from sympy.plotting import plot3d

# %%
# definiramo simbole x i y da bi ih mogli koristiti u formulama
x, y = symbols('x y')
f = asin(sqrt((x-y)/x)) # definiramo zadanu funkciju
f # prikazujemo funkciju
# Out:
# asin(sqrt((x - y)/x))

# %%
# Parcijalna derivacija po x
dfdx = diff(f, x)
# diff() je metoda sympy za rješavanje derivacija; 
# prvi argument je funkcija, drugi argument po čemu se derivira; 
# ako nema dvije varijable se ne mora dodavati drugi argument
dfdx
# Out:
# x*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(sqrt(1 - (x - y)/x)*(x - y))

# %%
# Parcijalna derivacija po y
dfdy = diff(f, y)
dfdy
# Out:
# -sqrt((x - y)/x)/(2*sqrt(1 - (x - y)/x)*(x - y))

# %%
# Parcijalna derivacija drugog reda po x
d2fdx2 = diff(dfdx, x)
# kako bi izračunali derivaciju drugog reda, deriviramo po derivaciji prvog reda
d2fdx2
# Out:
# x**2*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))**2/(sqrt(1 - (x - y)/x)*(x - y)**2) + x*sqrt((x - y)/x)*(-1/x**2 + (x - y)/x**3)/(sqrt(1 - (x - y)/x)*(x - y)) - x*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(sqrt(1 - (x - y)/x)*(x - y)**2) + x*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))**2/((1 - (x - y)/x)**(3/2)*(x - y)) + sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(sqrt(1 - (x - y)/x)*(x - y))

# %%
# Parcijalna derivacija drugog reda po y
d2fdy2 = diff(dfdy, y)
d2fdy2
# Out:
# -sqrt((x - y)/x)/(4*sqrt(1 - (x - y)/x)*(x - y)**2) + sqrt((x - y)/x)/(4*x*(1 - (x - y)/x)**(3/2)*(x - y))

# %%
# Parcijalna derivacija drugog reda po xy
d2fdxdy = diff(dfdx, y)
d2fdxdy
# Out:
# x*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(2*sqrt(1 - (x - y)/x)*(x - y)**2) - sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(2*(1 - (x - y)/x)**(3/2)*(x - y)) + sqrt((x - y)/x)/(2*x*sqrt(1 - (x - y)/x)*(x - y))

# %%
# Parcijalna derivacija drugog reda po yx
d2fdydx = diff(dfdy, x)
d2fdydx
# Out:
# -x*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(2*sqrt(1 - (x - y)/x)*(x - y)**2) + sqrt((x - y)/x)/(2*sqrt(1 - (x - y)/x)*(x - y)**2) - sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(2*(1 - (x - y)/x)**(3/2)*(x - y))

# %%
# Parcijalna derivacija po x u točki T(9,5)
dfdx_T = dfdx.subs({x:9, y:5})
# subs() je metoda sympy za uvrštavanje vrijednosti u formulu
dfdx_T
# Out:
# sqrt(5)/36

# %%
# Parcijalna derivacija po y u točki T(9,5)
dfdy_T = dfdy.subs({x:9, y:5})
dfdy_T
# Out:
# -sqrt(5)/20

# %%
# Parcijalna derivacija drugog reda po x u točki T(9,5)
d2fdx2_T = d2fdx2.subs({x:9, y:5})
d2fdx2_T
# Out:
# -17*sqrt(5)/2592

# %%
# Parcijalna derivacija drugog reda po y u točki T(9,5)
d2fdy2_T = d2fdy2.subs({x:9, y:5})
d2fdy2_T
# Out:
# -sqrt(5)/800

# %%
# Parcijalna derivacija drugog reda po xy u točki T(9,5)
d2fdxdy_T = d2fdxdy.subs({x:9, y:5})
d2fdxdy_T
# Out:
# sqrt(5)/160

# %%
# Parcijalna derivacija drugog reda po yx u točki T(9,5)
d2fdydx_T = d2fdydx.subs({x:9, y:5})
d2fdydx_T
# Out:
# sqrt(5)/160

# %%
# prikazivanje funkcije u trodimenzionalnom prostoru
funkcija = "Funkcija: " + str(f) # određivanje naslova kao string
plot3d(f, title=funkcija)

# %%
# prikazivanje prve derivacije po x u trodimenzionalnom prostoru
derivacija_x = "Derivacija prvog reda po x:\n" + str(dfdx)
plot3d(dfdx, title=derivacija_x)
# nažalost Python bilježnica ne može pokrenuti ovu funkciju
# odgovor se nalazi na https://replit.com/@marinolinic/Marino-Linic#main.py
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in true_divide

# %%
# prikazivanje prve derivacije po y u trodimenzionalnom prostoru
derivacija_y = "Derivacija prvog reda po y:\n" + str(dfdy)
plot3d(dfdy, title=derivacija_y)
# nažalost Python bilježnica ne može pokrenuti ovu funkciju
# odgovor se nalazi na https://replit.com/@marinolinic/Marino-Linic#main.py
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in true_divide

# %%
print("{} {}".format("f(x,y) =", f))
print("\n")
print("{} {}".format("Parcijalna derivacija prvog reda po x:", dfdx))
print("{} {}".format("Parcijalna derivacija prvog reda po y:", dfdy))
print("{} {}".format("Parcijalna derivacija drugog reda po x:", d2fdx2))
print("{} {}".format("Parcijalna derivacija drugog reda po y:", d2fdy2))
print("{} {}".format("Parcijalna derivacija drugog reda po xy:", d2fdxdy))
print("{} {}".format("Parcijalna derivacija drugog reda po yx:", d2fdydx))
print("\n")
print("{} {}".format("Parcijalna derivacija po x u točki T(9,5):", dfdx_T))
print("{} {}".format("Parcijalna derivacija po y u točki T(9,5):", dfdy_T))
print("{} {}".format("Parcijalna derivacija drugog reda po x u točki T(9,5):", d2fdx2_T))
print("{} {}".format("Parcijalna derivacija drugog reda po y u točki T(9,5):", d2fdy2_T))
print("{} {}".format("Parcijalna derivacija drugog reda po xy u točki T(9,5):", d2fdxdy_T))
print("{} {}".format("Parcijalna derivacija drugog reda po yx u točki T(9,5):", d2fdydx_T))
# Out:
# f(x,y) = asin(sqrt((x - y)/x))
#
#
# Parcijalna derivacija prvog reda po x: x*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(sqrt(1 - (x - y)/x)*(x - y))
# Parcijalna derivacija prvog reda po y: -sqrt((x - y)/x)/(2*sqrt(1 - (x - y)/x)*(x - y))
# Parcijalna derivacija drugog reda po x: x**2*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))**2/(sqrt(1 - (x - y)/x)*(x - y)**2) + x*sqrt((x - y)/x)*(-1/x**2 + (x - y)/x**3)/(sqrt(1 - (x - y)/x)*(x - y)) - x*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(sqrt(1 - (x - y)/x)*(x - y)**2) + x*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))**2/((1 - (x - y)/x)**(3/2)*(x - y)) + sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(sqrt(1 - (x - y)/x)*(x - y))
# Parcijalna derivacija drugog reda po y: -sqrt((x - y)/x)/(4*sqrt(1 - (x - y)/x)*(x - y)**2) + sqrt((x - y)/x)/(4*x*(1 - (x - y)/x)**(3/2)*(x - y))
# Parcijalna derivacija drugog reda po xy: x*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(2*sqrt(1 - (x - y)/x)*(x - y)**2) - sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(2*(1 - (x - y)/x)**(3/2)*(x - y)) + sqrt((x - y)/x)/(2*x*sqrt(1 - (x - y)/x)*(x - y))
# Parcijalna derivacija drugog reda po yx: -x*sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(2*sqrt(1 - (x - y)/x)*(x - y)**2) + sqrt((x - y)/x)/(2*sqrt(1 - (x - y)/x)*(x - y)**2) - sqrt((x - y)/x)*(1/(2*x) - (x - y)/(2*x**2))/(2*(1 - (x - y)/x)**(3/2)*(x - y))
#
#
# Parcijalna derivacija po x u točki T(9,5): sqrt(5)/36
# Parcijalna derivacija po y u točki T(9,5): -sqrt(5)/20
# Parcijalna derivacija drugog reda po x u točki T(9,5): -17*sqrt(5)/2592
# Parcijalna derivacija drugog reda po y u točki T(9,5): -sqrt(5)/800
# Parcijalna derivacija drugog reda po xy u točki T(9,5): sqrt(5)/160
# Parcijalna derivacija drugog reda po yx u točki T(9,5): sqrt(5)/160
